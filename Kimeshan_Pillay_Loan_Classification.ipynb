# %% [markdown]
# #### **Loan Classification**
#
# A Naïve Bayes classification model will be used to determine whether an individual will fully pay their loan.

# %% [markdown]
# **Standard Dependencies**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# **The Dataset**

# %%
MY_DF = pd.read_csv(r'https://raw.githubusercontent.com/ST10437317/kpillay-firstrepo-vc/main/ST10437317_LOAN_DATA.csv')
MY_DF.head(10)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
# 5              1         credit_card    0.0788       125.13       11.904968
# 6              1  debt_consolidation    0.1496       194.02       10.714418
# 7              1           all_other    0.1114       131.22       11.002100
# 8              1    home_improvement    0.1134        87.19       11.407565
# 9              1  debt_consolidation    0.1221        84.12       10.203592
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# ...

# %% [markdown]
# **Features Information**

# %%
MY_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# **Descriptive Statistics**

# %%
MY_DF.describe().T
# Out:
#                     count          mean           std         min  \
# credit.policy      9578.0      0.804970      0.396245    0.000000
# int.rate           9578.0      0.122640      0.026847    0.060000
# installment        9578.0    319.089413    207.071301   15.670000
# log.annual.inc     9578.0     10.932117      0.614813    7.547502
# dti                9578.0     12.606679      6.883970    0.000000
# fico               9578.0    710.846314     37.970537  612.000000
# days.with.cr.line  9578.0   4560.767197   2496.930377  178.958333
# revol.bal          9578.0  16913.963876  33756.189557    0.000000
# revol.util         9578.0     46.799236     29.014417    0.000000
# inq.last.6mths     9578.0      1.577469      2.200245    0.000000
# delinq.2yrs        9578.0      0.163708      0.546215    0.000000
# pub.rec            9578.0      0.062122      0.262126    0.000000
# not.fully.paid     9578.0      0.160054      0.366676    0.000000
#
# ...

# %%
sns.countplot(data = MY_DF, x = 'purpose', hue = 'not.fully.paid')
plt.xticks(rotation = 45, ha = 'right')
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'debt_consolidation'),
#   Text(1, 0, 'credit_card'),
#   Text(2, 0, 'all_other'),
#   Text(3, 0, 'home_improvement'),
#   Text(4, 0, 'small_business'),
#   Text(5, 0, 'major_purchase'),
#   Text(6, 0, 'educational')])

# %% [markdown]
# **Preprocessing**

# %%
L_ENCODE = LabelEncoder()
MY_DF.replace(MY_DF['purpose'].values, np.int64(L_ENCODE.fit_transform(MY_DF['purpose'])), inplace = True)
MY_DF
# Out:
#       credit.policy  purpose  int.rate  installment  log.annual.inc    dti  \
# 0                 1        2    0.1189       829.10       11.350407  19.48
# 1                 1        1    0.1071       228.22       11.082143  14.29
# 2                 1        2    0.1357       366.86       10.373491  11.63
# 3                 1        2    0.1008       162.34       11.350407   8.10
# 4                 1        1    0.1426       102.92       11.299732  14.97
# ...             ...      ...       ...          ...             ...    ...
# 9573              0        0    0.1461       344.76       12.180755  10.39
# 9574              0        0    0.1253       257.70       11.141862   0.21
# 9575              0        2    0.1071        97.81       10.596635  13.09
# 9576              0        4    0.1600       351.58       10.819778  19.18
# 9577              0        2    0.1392       853.43       11.264464  16.28
#
# ...

# %%
MY_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   int64
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(8)
# memory usage: 1.0 MB

# %% [markdown]
# **Additional Visualizations**

# %%
MY_DF['not.fully.paid'].value_counts().plot(kind = 'bar')
plt.xlabel('Fully Paid?')
plt.ylabel('No. Of Occurences')
plt.show()

# %%
plt.figure(figsize = (11, 10))
sns.heatmap(MY_DF.corr(), cmap = "Blues", annot = True)
plt.tight_layout
plt.show()

# %% [markdown]
# **Training And Testing Splits**

# %%
X = MY_DF.drop(columns = ['not.fully.paid'])
y = MY_DF['not.fully.paid']

# %%
X.head()
# Out:
#    credit.policy  purpose  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1        2    0.1189       829.10       11.350407  19.48   737
# 1              1        1    0.1071       228.22       11.082143  14.29   707
# 2              1        2    0.1357       366.86       10.373491  11.63   682
# 3              1        2    0.1008       162.34       11.350407   8.10   712
# 4              1        1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec
# 0        0
# 1        0
# 2        0
# ...

# %%
pd.DataFrame(y.head())
# Out:
#    not.fully.paid
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (6417, 3161, 6417, 3161)

# %% [markdown]
# **Model Instance**

# %%
NB_MODEL = GaussianNB()
NB_MODEL.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %% [markdown]
# **Fitting And Predictions**

# %%
NB_MODEL.fit(X_train, y_train)
y_preds = NB_MODEL.predict(X_test)

# %%
pd.DataFrame({'True Label' : y_test, 'Predicted Label' : y_preds})
# Out:
#       True Label  Predicted Label
# 8558           0                0
# 4629           0                0
# 1383           1                0
# 8142           0                0
# 1768           0                0
# ...          ...              ...
# 734            0                0
# 3518           0                0
# 3526           0                0
# 1174           1                0
# 8336           1                0
#
# [3161 rows x 2 columns]

# %% [markdown]
# **Model Assessment**

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      2650
#            1       0.31      0.09      0.13       511
#
#     accuracy                           0.82      3161
#    macro avg       0.58      0.52      0.52      3161
# weighted avg       0.76      0.82      0.78      3161

# %%
CMD = ConfusionMatrixDisplay(confusion_matrix(y_test, y_preds))
CMD.plot()
plt.show()
